# %% [markdown]
# #### 12/8/2020
# ## COMP 541 - Assignment 4 - Team 6
# ### Table of Contents:
# * [1. Feature selection and improve accuracy of data mining results ](#1)
# * &emsp;[1.1. Feature Selection](#11)
# * &emsp;&emsp;[1.1.1. Importing Libraries](#111)
# * &emsp;&emsp;[1.1.2. Converting categorical data to numerical](#112)
# * &emsp;&emsp;[1.1.3. Correlation Matrix](#113)
# * &emsp;&emsp;[1.1.4. Heat-Map of correlation Matrix](#114)
# * &emsp;&emsp;[1.1.5. Relevant attributes to improve the accuracy of data mining results](#115)

# %% [markdown]
# # 1. Feature selection and improve accuracy of data mining results <a class="anchor" id="1"></a>

# %% [markdown]
# Select relevant attributes from your dataset to improve the accuracy of data mining results.

# %% [markdown]
# ## 1.1 Feature Selection <a class="anchor" id="11"></a>

# %% [markdown]
# ### 1.1.1. Importing Libraries <a class="anchor" id="111"></a>

# %%
import pandas as pd 
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1.2. Converting categorical data to numerical <a class="anchor" id="112"></a>

# %%
df = pd.read_csv('data/training_data.csv')

# %%
categorical_features = ['company','country','director','genre','rating','released','star','year',
                        'writer','original_title','overview','tagline','title','genres_edited',
                        'spoken_languages_edited','production_countries_edited','keywords_edited']
continuous_features = ['budget','runtime','score','votes','popularity']
normalized_features = [e+'_norm' for e in continuous_features]
target_features = ['isprofit','profitability_ratio']
all_features = categorical_features + continuous_features + normalized_features + target_features

# %%
df['company']=df['company'].astype('category').cat.codes
df['country']=df['country'].astype('category').cat.codes
df['director']=df['director'].astype('category').cat.codes
df['genre']=df['genre'].astype('category').cat.codes
df['rating']=df['rating'].astype('category').cat.codes
df['star']=df['star'].astype('category').cat.codes
df['writer']=df['writer'].astype('category').cat.codes
# df['adult']=df['adult'].astype('category').cat.codes
# column "adult" has dropped as it all had a value of "0"

# %% [markdown]
# ### 1.1.3. Correlation Matrix <a class="anchor" id="113"></a>

# %%
corr_df=df[all_features].corr()

# %%
corr_df
# Out:
#                       company   country  director     genre    rating  \
# company              1.000000 -0.017782  0.002874 -0.073149 -0.101551
# country             -0.017782  1.000000  0.018204 -0.002472  0.026836
# director             0.002874  0.018204  1.000000  0.070478  0.014242
# genre               -0.073149 -0.002472  0.070478  1.000000  0.145487
# rating              -0.101551  0.026836  0.014242  0.145487  1.000000
# star                 0.023274 -0.045394  0.057815  0.012269  0.012840
# year                -0.024054 -0.077195 -0.004846  0.019018 -0.041962
# writer               0.012118 -0.018488  0.126109  0.007385 -0.004130
# budget               0.097531  0.059626 -0.001278 -0.285296 -0.197965
# runtime              0.005454 -0.056416  0.065080  0.030601  0.188227
# score               -0.015315 -0.085744  0.075730  0.095737  0.127476
# votes                0.019071  0.008901  0.063488 -0.104413  0.073216
# popularity           0.049744  0.007047  0.038147 -0.142618 -0.045281
# budget_norm          0.097531  0.059626 -0.001278 -0.285296 -0.197965
# runtime_norm         0.005454 -0.056416  0.065080  0.030601  0.188227
# score_norm          -0.015315 -0.085744  0.075730  0.095737  0.127476
# votes_norm           0.019071  0.008901  0.063488 -0.104413  0.073216
# popularity_norm      0.049744  0.007047  0.038147 -0.142618 -0.045281
# isprofit             0.022694  0.129073 -0.018902  0.029489 -0.080832
# profitability_ratio  0.018585  0.156783  0.013691  0.047263 -0.091355
#
#                          star      year    writer    budget   runtime  \
# company              0.023274 -0.024054  0.012118  0.097531  0.005454
# country             -0.045394 -0.077195 -0.018488  0.059626 -0.056416
# director             0.057815 -0.004846  0.126109 -0.001278  0.065080
# genre                0.012269  0.019018  0.007385 -0.285296  0.030601
# rating               0.012840 -0.041962 -0.004130 -0.197965  0.188227
# star                 1.000000 -0.011091 -0.000693  0.026384  0.054634
# year                -0.011091  1.000000 -0.012606  0.233329 -0.021891
# writer              -0.000693 -0.012606  1.000000 -0.040317 -0.002660
# budget               0.026384  0.233329 -0.040317  1.000000  0.245678
# runtime              0.054634 -0.021891 -0.002660  0.245678  1.000000
# score                0.043207  0.017631  0.034381 -0.095490  0.392081
# votes                0.019481  0.299654  0.008656  0.377543  0.201551
# popularity           0.000969  0.200500 -0.011702  0.336131  0.110656
# budget_norm          0.026384  0.233329 -0.040317  1.000000  0.245678
# runtime_norm         0.054634 -0.021891 -0.002660  0.245678  1.000000
# score_norm           0.043207  0.017631  0.034381 -0.095490  0.392081
# votes_norm           0.019481  0.299654  0.008656  0.377543  0.201551
# popularity_norm      0.000969  0.200500 -0.011702  0.336131  0.110656
# isprofit            -0.016117 -0.065895  0.002278 -0.067468 -0.032826
# profitability_ratio -0.014121 -0.133509  0.038103 -0.139417 -0.042485
#
#                         score     votes  popularity  budget_norm  \
# company             -0.015315  0.019071    0.049744     0.097531
# country             -0.085744  0.008901    0.007047     0.059626
# director             0.075730  0.063488    0.038147    -0.001278
# genre                0.095737 -0.104413   -0.142618    -0.285296
# rating               0.127476  0.073216   -0.045281    -0.197965
# star                 0.043207  0.019481    0.000969     0.026384
# year                 0.017631  0.299654    0.200500     0.233329
# writer               0.034381  0.008656   -0.011702    -0.040317
# budget              -0.095490  0.377543    0.336131     1.000000
# runtime              0.392081  0.201551    0.110656     0.245678
# score                1.000000  0.430192    0.213426    -0.095490
# votes                0.430192  1.000000    0.499493     0.377543
# popularity           0.213426  0.499493    1.000000     0.336131
# budget_norm         -0.095490  0.377543    0.336131     1.000000
# runtime_norm         0.392081  0.201551    0.110656     0.245678
# score_norm           1.000000  0.430192    0.213426    -0.095490
# votes_norm           0.430192  1.000000    0.499493     0.377543
# popularity_norm      0.213426  0.499493    1.000000     0.336131
# isprofit             0.137253  0.286978    0.182108    -0.067468
# profitability_ratio  0.147756  0.268620    0.175987    -0.139417
#
#                      runtime_norm  score_norm  votes_norm  popularity_norm  \
# company                  0.005454   -0.015315    0.019071         0.049744
# country                 -0.056416   -0.085744    0.008901         0.007047
# director                 0.065080    0.075730    0.063488         0.038147
# genre                    0.030601    0.095737   -0.104413        -0.142618
# rating                   0.188227    0.127476    0.073216        -0.045281
# star                     0.054634    0.043207    0.019481         0.000969
# year                    -0.021891    0.017631    0.299654         0.200500
# writer                  -0.002660    0.034381    0.008656        -0.011702
# budget                   0.245678   -0.095490    0.377543         0.336131
# runtime                  1.000000    0.392081    0.201551         0.110656
# score                    0.392081    1.000000    0.430192         0.213426
# votes                    0.201551    0.430192    1.000000         0.499493
# popularity               0.110656    0.213426    0.499493         1.000000
# budget_norm              0.245678   -0.095490    0.377543         0.336131
# runtime_norm             1.000000    0.392081    0.201551         0.110656
# score_norm               0.392081    1.000000    0.430192         0.213426
# votes_norm               0.201551    0.430192    1.000000         0.499493
# popularity_norm          0.110656    0.213426    0.499493         1.000000
# isprofit                -0.032826    0.137253    0.286978         0.182108
# profitability_ratio     -0.042485    0.147756    0.268620         0.175987
#
#                      isprofit  profitability_ratio
# company              0.022694             0.018585
# country              0.129073             0.156783
# director            -0.018902             0.013691
# genre                0.029489             0.047263
# rating              -0.080832            -0.091355
# star                -0.016117            -0.014121
# year                -0.065895            -0.133509
# writer               0.002278             0.038103
# budget              -0.067468            -0.139417
# runtime             -0.032826            -0.042485
# score                0.137253             0.147756
# votes                0.286978             0.268620
# popularity           0.182108             0.175987
# budget_norm         -0.067468            -0.139417
# runtime_norm        -0.032826            -0.042485
# score_norm           0.137253             0.147756
# votes_norm           0.286978             0.268620
# popularity_norm      0.182108             0.175987
# isprofit             1.000000             0.771496
# profitability_ratio  0.771496             1.000000

# %% [markdown]
# ### 1.1.4. Heat-Map of correlation Matrix <a class="anchor" id="114"></a>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr_df,cmap='coolwarm',vmin=-1, vmax=1,annot=True,linewidth=.5);

# %% [markdown]
# ### 1.1.5. Relevant attributes to improve the accuracy of data mining results <a class="anchor" id="115"></a>

# %%
corr_df_features = set()
for i in range(len(corr_df.columns)-2):
    if corr_df.iloc[i,14]<-0.1 or corr_df.iloc[i,14]>0.1 or \
        corr_df.iloc[i,13]<-0.1 or corr_df.iloc[i,13]>0.1:
        corr_df_features.add(corr_df.columns[i])

# %%
corr_df_features
# Out:
# {'budget',
#  'budget_norm',
#  'genre',
#  'popularity',
#  'popularity_norm',
#  'rating',
#  'runtime',
#  'runtime_norm',
#  'score',
#  'score_norm',
#  'votes',
#  'votes_norm',
#  'year'}

# %%
df[list(corr_df_features)+['isprofit','profitability_ratio']].to_csv('data/final_training_data.csv')
